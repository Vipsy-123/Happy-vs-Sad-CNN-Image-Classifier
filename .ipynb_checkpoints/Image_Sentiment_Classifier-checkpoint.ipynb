# %%
pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting opencv-python
#   Using cached opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (3.5.1)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers>=23.5.26 (from tensorflow)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=2.9.0 (from tensorflow)
#   Using cached h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting ml-dtypes==0.2.0 (from tensorflow)
#   Using cached ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.23.5 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.26.1)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (21.3)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow)
#   Using cached protobuf-4.25.0-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.local/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow)
#   Using cached wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (14 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.59.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.15,>=2.14 (from tensorflow)
#   Using cached tensorboard-2.14.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0 (from tensorflow)
#   Using cached tensorflow_estimator-2.14.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.15,>=2.14.0 (from tensorflow)
#   Using cached keras-2.14.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting python_version>"3.7" (from tensorflow-gpu)
#   Using cached python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.15,>=2.14->tensorflow)
#   Using cached google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.15,>=2.14->tensorflow)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.15,>=2.14->tensorflow)
#   Using cached Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.15,>=2.14->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.15,>=2.14->tensorflow)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2020.6.20)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow)
#   Using cached MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow)
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.0)
# Using cached tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
# Using cached ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Using cached opencv_python-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached grpcio-1.59.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Using cached h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Using cached keras-2.14.0-py3-none-any.whl (1.7 MB)
# Downloading libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 5.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading protobuf-4.25.0-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.4/294.4 kB 6.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 5.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 5.9 MB/s eta 0:00:00m eta 0:00:0100:01
# Downloading tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 5.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.3/183.3 kB 8.2 MB/s eta 0:00:00
# Downloading Markdown-3.5.1-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 7.2 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 4.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-c442fnkm/tensorflow-gpu_673197a9ca134c12aa027ad058140dec/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# ERROR: Could not build wheels for tensorflow-gpu, which is required to install pyproject.toml-based projects
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in ./.local/lib/python3.10/site-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.local/lib/python3.10/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.10/site-packages (from tensorflow) (4.25.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.local/lib/python3.10/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.10/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.10/site-packages (from tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in ./.local/lib/python3.10/site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.local/lib/python3.10/site-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2020.6.20)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import os

# %%
pip list
# Out:
# Package                              Version          Editable project location
# ------------------------------------ ---------------- --------------------------------------------------------------
# absl-py                              2.0.0
# action-msgs                          1.2.1
# action-tutorials-interfaces          0.20.3
# action-tutorials-py                  0.20.3
# actionlib-msgs                       4.2.3
# ament-cmake-test                     1.3.5
# ament-copyright                      0.12.8
# ament-cppcheck                       0.12.8
# ament-cpplint                        0.12.8
# ament-flake8                         0.12.8
# ament-index-python                   1.4.0
# ament-lint                           0.12.8
# ament-lint-cmake                     0.12.8
# ament-package                        0.14.0
# ament-pep257                         0.12.8
# ament-uncrustify                     0.12.8
# ament-xmllint                        0.12.8
# angles                               1.15.0
# anyio                                4.0.0
# appdirs                              1.4.4
# apturl                               0.5.2
# argcomplete                          1.8.1
# argon2-cffi                          23.1.0
# argon2-cffi-bindings                 21.2.0
# arrow                                1.3.0
# asttokens                            2.4.1
# astunparse                           1.6.3
# async-lru                            2.0.4
# attrs                                23.1.0
# Babel                                2.13.1
# bcrypt                               3.2.0
# beautifulsoup4                       4.10.0
# beniget                              0.4.1
# bleach                               6.1.0
# blinker                              1.4
# Brlapi                               0.8.3
# Brotli                               1.0.9
# builtin-interfaces                   1.2.1
# cachetools                           5.3.2
# catkin-pkg-modules                   1.0.0
# certifi                              2020.6.20
# cffi                                 1.16.0
# chardet                              4.0.0
# charset-normalizer                   3.3.2
# click                                8.0.3
# colcon-argcomplete                   0.3.3
# colcon-bash                          0.5.0
# colcon-cd                            0.1.1
# colcon-cmake                         0.2.28
# colcon-common-extensions             0.3.0
# colcon-core                          0.15.0
# colcon-defaults                      0.2.8
# colcon-devtools                      0.2.4
# colcon-installed-package-information 0.1.0
# colcon-library-path                  0.2.1
# colcon-metadata                      0.2.5
# colcon-notification                  0.2.15
# colcon-output                        0.2.13
# colcon-override-check                0.0.1
# colcon-package-information           0.3.3
# colcon-package-selection             0.2.10
# colcon-parallel-executor             0.3.0
# colcon-pkg-config                    0.1.0
# colcon-powershell                    0.4.0
# colcon-python-setup-py               0.2.8
# colcon-recursive-crawl               0.2.3
# colcon-ros                           0.4.1
# colcon-test-result                   0.3.8
# colcon-zsh                           0.5.0
# colorama                             0.4.4
# comm                                 0.2.0
# command-not-found                    0.3
# composition-interfaces               1.2.1
# configobj                            5.0.6
# control-msgs                         4.4.0
# controller-manager                   2.32.0
# controller-manager-msgs              2.32.0
# cov-core                             1.15.0
# coverage                             6.2
# cryptography                         3.4.8
# cupshelpers                          1.0
# cv-bridge                            3.2.1
# cycler                               0.11.0
# dbus-python                          1.2.18
# debugpy                              1.8.0
# decorator                            4.4.2
# defer                                1.0.6
# defusedxml                           0.7.1
# demo-nodes-py                        0.20.3
# diagnostic-msgs                      4.2.3
# distlib                              0.3.4
# distro                               1.7.0
# distro-info                          1.1+ubuntu0.1
# docutils                             0.17.1
# domain-coordinator                   0.10.0
# duplicity                            0.8.21
# ebot-docking                         0.0.0
# empy                                 3.3.4
# example-interfaces                   0.9.3
# examples-rclpy-executors             0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_executors
# examples-rclpy-guard-conditions      0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_guard_conditions
# examples-rclpy-minimal-action-client 0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_minimal_action_client
# examples-rclpy-minimal-action-server 0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_minimal_action_server
# examples-rclpy-minimal-client        0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_minimal_client
# examples-rclpy-minimal-publisher     0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_minimal_publisher
# examples-rclpy-minimal-service       0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_minimal_service
# examples-rclpy-minimal-subscriber    0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_minimal_subscriber
# examples-rclpy-pointcloud-publisher  0.15.1           /home/vipul/ros2_ws/build/examples_rclpy_pointcloud_publisher
# exceptiongroup                       1.1.3
# executing                            2.0.1
# fasteners                            0.14.1
# fastjsonschema                       2.18.1
# flake8                               4.0.1
# flatbuffers                          23.5.26
# fonttools                            4.29.1
# fqdn                                 1.5.1
# fs                                   2.4.12
# future                               0.18.2
# gast                                 0.5.4
# gazebo-msgs                          3.7.0
# generate-parameter-library-py        0.3.6
# geometry-msgs                        4.2.3
# google-auth                          2.23.4
# google-auth-oauthlib                 1.0.0
# google-pasta                         0.2.0
# grpcio                               1.59.2
# h5py                                 3.10.0
# html5lib                             1.1
# httplib2                             0.20.2
# idna                                 3.3
# image-geometry                       3.2.1
# importlib-metadata                   4.6.4
# iniconfig                            1.1.1
# interactive-markers                  2.3.2
# ipykernel                            6.26.0
# ipython                              8.17.2
# isoduration                          20.11.0
# jedi                                 0.19.1
# jeepney                              0.7.1
# Jinja2                               3.0.3
# joint-state-publisher                2.4.0
# json5                                0.9.14
# jsonpointer                          2.4
# jsonschema                           4.19.2
# jsonschema-specifications            2023.7.1
# jupyter_client                       8.6.0
# jupyter_core                         5.5.0
# jupyter-events                       0.9.0
# jupyter-lsp                          2.2.0
# jupyter_server                       2.10.0
# jupyter_server_terminals             0.4.4
# jupyterlab                           4.0.8
# jupyterlab-pygments                  0.2.2
# jupyterlab_server                    2.25.1
# keras                                2.14.0
# keyring                              23.5.0
# kiwisolver                           1.3.2
# language-selector                    0.1
# lark                                 1.1.1
# laser-geometry                       2.4.0
# launch                               1.0.4
# launch-param-builder                 0.1.1
# launch-ros                           0.19.6
# launch-testing                       1.0.4
# launch-testing-examples              0.15.1           /home/vipul/ros2_ws/build/launch_testing_examples
# launch-testing-ros                   0.19.6
# launch-xml                           1.0.4
# launch-yaml                          1.0.4
# launchpadlib                         1.10.16
# lazr.restfulclient                   0.14.4
# lazr.uri                             1.0.6
# libclang                             16.0.6
# lifecycle-msgs                       1.2.1
# linkattacher-msgs                    0.0.0
# lockfile                             0.12.2
# logging-demo                         0.20.3
# louis                                3.20.0
# lxml                                 4.8.0
# lz4                                  3.1.3+dfsg
# macaroonbakery                       1.3.1
# machine                              0.0.1
# Mako                                 1.1.3
# map-msgs                             2.1.0
# Markdown                             3.5.1
# MarkupSafe                           2.1.3
# matplotlib                           3.5.1
# matplotlib-inline                    0.1.6
# mccabe                               0.6.1
# message-filters                      4.3.3
# mistune                              3.0.2
# ml-dtypes                            0.2.0
# monotonic                            1.6
# more-itertools                       8.10.0
# moveit-configs-utils                 2.5.5
# moveit-msgs                          2.2.1
# mpi4py                               3.1.3
# mpmath                               0.0.0
# nav-msgs                             4.2.3
# nbclient                             0.9.0
# nbconvert                            7.11.0
# nbformat                             5.9.2
# nest-asyncio                         1.5.8
# netifaces                            0.11.0
# nose2                                0.9.2
# notebook                             7.0.6
# notebook_shim                        0.2.3
# notify2                              0.3
# numpy                                1.23.5
# oauthlib                             3.2.0
# object-recognition-msgs              2.0.0
# octomap-msgs                         2.0.0
# olefile                              0.46
# opencv-contrib-python                4.7.0.72
# opt-einsum                           3.3.0
# osrf-pycommon                        2.0.2
# overrides                            7.4.0
# packaging                            21.3
# pandas                               2.1.2
# pandocfilters                        1.5.0
# paramiko                             2.9.3
# parso                                0.8.3
# pcl-msgs                             1.0.0
# pendulum-msgs                        0.20.3
# pexpect                              4.8.0
# Pillow                               9.0.1
# pip                                  23.3.1
# platformdirs                         3.11.0
# pluggy                               0.13.0
# ply                                  3.11
# prometheus-client                    0.18.0
# prompt-toolkit                       3.0.39
# protobuf                             4.25.0
# psutil                               5.9.0
# ptyprocess                           0.7.0
# pure-eval                            0.2.2
# py                                   1.10.0
# pyasn1                               0.5.0
# pyasn1-modules                       0.3.0
# pycairo                              1.20.1
# pycodestyle                          2.8.0
# pycparser                            2.21
# pycrypto                             2.6.1
# pycups                               2.0.1
# pydocstyle                           6.1.1
# pydot                                1.4.2
# pyflakes                             2.4.0
# Pygments                             2.11.2
# PyGObject                            3.42.1
# pygraphviz                           1.7
# PyJWT                                2.3.0
# pymacaroons                          0.13.0
# pymoveit2                            2.1.0
# PyNaCl                               1.5.0
# pyparsing                            2.4.7
# PyQt5                                5.15.6
# PyQt5-sip                            12.9.1
# pyRFC3339                            1.1
# pytest                               6.2.5
# pytest-cov                           3.0.0
# python-apt                           2.4.0+ubuntu2
# python-dateutil                      2.8.2
# python-debian                        0.1.43+ubuntu1.1
# python-json-logger                   2.0.7
# python-qt-binding                    1.1.1
# pythran                              0.10.0
# pytz                                 2022.1
# pyxdg                                0.27
# PyYAML                               5.4.1
# pyzmq                                25.1.1
# qt-dotgraph                          2.2.2
# qt-gui                               2.2.2
# qt-gui-cpp                           2.2.2
# qt-gui-py-common                     2.2.2
# quality-of-service-demo-py           0.20.3
# rcl-interfaces                       1.2.1
# rclpy                                3.3.10
# rcutils                              5.1.3
# referencing                          0.30.2
# reportlab                            3.6.8
# requests                             2.31.0
# requests-oauthlib                    1.3.1
# resource-retriever                   3.1.1
# rfc3339-validator                    0.1.4
# rfc3986-validator                    0.1.1
# rmw-dds-common                       1.6.0
# roman                                3.3
# ros2action                           0.18.7
# ros2bag                              0.15.8
# ros2cli                              0.18.7
# ros2component                        0.18.7
# ros2controlcli                       2.32.0
# ros2doctor                           0.18.7
# ros2interface                        0.18.7
# ros2launch                           0.19.6
# ros2lifecycle                        0.18.7
# ros2multicast                        0.18.7
# ros2node                             0.18.7
# ros2param                            0.18.7
# ros2pkg                              0.18.7
# ros2run                              0.18.7
# ros2service                          0.18.7
# ros2topic                            0.18.7
# rosbag2-interfaces                   0.15.8
# rosbag2-py                           0.15.8
# rosdistro-modules                    0.9.0
# rosgraph-msgs                        1.2.1
# rosidl-adapter                       3.1.5
# rosidl-cli                           3.1.5
# rosidl-cmake                         3.1.5
# rosidl-generator-c                   3.1.5
# rosidl-generator-cpp                 3.1.5
# rosidl-generator-py                  0.14.4
# rosidl-parser                        3.1.5
# rosidl-runtime-py                    0.9.3
# rosidl-typesupport-c                 2.0.1
# rosidl-typesupport-cpp               2.0.1
# rosidl-typesupport-fastrtps-c        2.2.1
# rosidl-typesupport-fastrtps-cpp      2.2.1
# rosidl-typesupport-introspection-c   3.1.5
# rosidl-typesupport-introspection-cpp 3.1.5
# rospkg-modules                       1.5.0
# rpds-py                              0.12.0
# rpyutils                             0.2.1
# rqt-action                           2.0.1
# rqt-bag                              1.1.4
# rqt-bag-plugins                      1.1.4
# rqt-console                          2.0.2
# rqt-graph                            1.3.0
# rqt-gui                              1.1.5
# rqt-gui-py                           1.1.5
# rqt-msg                              1.2.0
# rqt-plot                             1.1.2
# rqt-publisher                        1.5.0
# rqt-py-common                        1.1.5
# rqt-py-console                       1.0.2
# rqt-reconfigure                      1.1.1
# rqt-service-caller                   1.0.5
# rqt-shell                            1.0.2
# rqt-srv                              1.0.3
# rqt-topic                            1.5.0
# rsa                                  4.9
# scipy                                1.8.0
# scripts                              3.7.0
# SecretStorage                        3.3.1
# Send2Trash                           1.8.2
# sensor-msgs                          4.2.3
# sensor-msgs-py                       4.2.3
# setuptools                           59.6.0
# shape-msgs                           4.2.3
# six                                  1.16.0
# sniffio                              1.3.0
# snowballstemmer                      2.2.0
# soupsieve                            2.3.1
# srdfdom                              2.0.4
# sros2                                0.10.4
# stack-data                           0.6.3
# statistics-msgs                      1.2.1
# std-msgs                             4.2.3
# std-srvs                             4.2.3
# stereo-msgs                          4.2.3
# sympy                                1.9
# systemd-python                       234
# teleop-twist-keyboard                2.3.2
# tensorboard                          2.14.1
# tensorboard-data-server              0.7.2
# tensorflow                           2.14.0
# tensorflow-estimator                 2.14.0
# tensorflow-io-gcs-filesystem         0.34.0
# termcolor                            2.3.0
# terminado                            0.17.1
# terminator                           2.1.1
# tf-transformations                   1.0.0
# tf2-geometry-msgs                    0.25.4
# tf2-kdl                              0.25.4
# tf2-msgs                             0.25.4
# tf2-py                               0.25.4
# tf2-ros-py                           0.25.4
# tf2-tools                            0.25.4
# tinycss2                             1.2.1
# toml                                 0.10.2
# tomli                                2.0.1
# topic-monitor                        0.20.3
# tornado                              6.3.3
# traitlets                            5.13.0
# trajectory-msgs                      4.2.3
# transforms3d                         0.4.1
# trimesh                              4.0.0
# turtlesim                            1.4.2
# typeguard                            2.2.2
# types-python-dateutil                2.8.19.14
# typing_extensions                    4.8.0
# tzdata                               2023.3
# ubuntu-advantage-tools               8001
# ubuntu-drivers-common                0.0.0
# ufoLib2                              0.13.1
# ufw                                  0.36.1
# unattended-upgrades                  0.1
# unicodedata2                         14.0.0
# unique-identifier-msgs               2.2.1
# urdfdom-py                           1.2.1
# uri-template                         1.3.0
# urllib3                              1.26.5
# usb-creator                          0.3.7
# visualization-msgs                   4.2.3
# wadllib                              1.3.6
# wcwidth                              0.2.9
# webcolors                            1.13
# webencodings                         0.5.1
# websocket-client                     1.6.4
# Werkzeug                             3.0.1
# wheel                                0.37.1
# wrapt                                1.14.1
# xacro                                2.0.8
# xdg                                  5
# xkit                                 0.0.0
# zipp                                 1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Avoid Out of Memory errors by setting GPU Memory Consumption Growth

gpus = tf.config.experimental.list_physical_devices('GPU') # Listing GPUs
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %%
import cv2
import imghdr

# %%
dat_dir = 'data'

# %%
image_exts = ['jpeg','jpg','bmp','png']
